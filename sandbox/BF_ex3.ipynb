# %%
from datetime import timedelta

import geopandas as gpd
import pandas as pd
import random

from pyparsing import results
from shapely.geometry import Point
import requests
import glob
import os
import timeit
import numpy as np
from pandas import Timedelta

# %%
my_globals = {}
exec("from osgeo import gdal", my_globals)

# %%
root = '/home/pier/'
samples = 40

# %%
gcp_total = gpd.read_file(r'/home/pier/PycharmProjects/CDSE_Benchmark/data/gcp.shp', where="q_score='5'")

# %%
random_points_gdf = gcp_total.sample(samples)
random_points_gdf.reset_index(drop=True, inplace=True)

# %%
random_points_gdf
# Out:
#            UID q_score     filename                     geometry
# 0   49QEG_0702       5  N23E111_L1C   POINT (111.48769 23.78867)
# 1   45TUN_1726       5  N46E084_L1C    POINT (84.58750 46.86056)
# 2   57VVK_0569       5  N63E159_L1C   POINT (159.06834 63.05595)
# 3   55WDM_1939       5  N64E146_L1C   POINT (146.69534 64.83558)
# 4   17RMK_3098       5  N26W082_L1C   POINT (-81.65890 26.42207)
# 5   57WVN_0161       5  N65E157_L1C   POINT (157.55100 65.41047)
# 6   18TYR_1319       5  N45W072_L1C   POINT (-71.78177 45.41070)
# 7   54VWQ_1619       5  N62E141_L1C   POINT (141.42562 62.31141)
# 8   49WDV_0171       5  N71E108_L1C   POINT (108.65238 71.80366)
# 9   18WWB_0263       5  N68W075_L1C   POINT (-74.19452 68.58178)
# 10  12WWV_1822       5  N67W110_L1C  POINT (-109.98578 67.30569)
# 11  36WWV_3922       5  N67E034_L1C    POINT (34.80249 67.53137)
# 12  47RNQ_0096       5  N30E099_L1C    POINT (99.24945 30.83502)
# 13  60WWB_3032       5  N69E178_L1C   POINT (178.33216 69.32610)
# 14  13WFP_0098       5  N66W102_L1C  POINT (-101.69940 66.02599)
# 15  43WEV_2868       5  N71E076_L1C    POINT (76.26120 71.89775)
# 16  35MNU_0061       5  S02E027_L1C    POINT (27.94024 -1.68885)
# 17  13WDT_4391       5  N69W108_L1C  POINT (-107.11308 69.61908)
# 18  38KQU_1429       5  S25E047_L1C   POINT (47.27122 -24.19188)
# 19  57WXS_1912       5  N69E162_L1C   POINT (162.34189 69.22794)
# 20  39UWU_3304       5  N52E051_L1C    POINT (51.14406 52.69844)
# 21  35PLK_0664       5  N08E025_L1C     POINT (25.97206 8.34952)
# 22  19MHM_2578       5  S08W066_L1C   POINT (-65.76891 -7.25495)
# 23  49RBQ_0730       5  N31E108_L1C   POINT (108.31011 31.01972)
# 24  21KVV_3585       5  S19W058_L1C  POINT (-57.57843 -18.40087)
# 25  26XNK_1453       5  N76W025_L1C   POINT (-24.24393 76.09557)
# 26  32TLT_1527       5  N47E007_L1C     POINT (7.08496 47.21500)
# 27  47XMD_0859       5  N75E096_L1C    POINT (96.05549 75.06332)
# 28  58WDC_0756       5  N69E163_L1C   POINT (163.13517 69.53255)
# 29  49RFL_1536       5  N27E112_L1C   POINT (112.96705 27.57236)
# 30  12VVR_0893       5  N63W113_L1C  POINT (-112.10402 63.39895)
# 31  53SNV_0272       5  N35E135_L1C   POINT (135.83679 35.62415)
# 32  09UVV_1165       5  N53W130_L1C  POINT (-129.20907 53.90592)
# 33  43WES_0301       5  N69E077_L1C    POINT (77.76601 69.23212)
# 34  23KKQ_0854       5  S24W048_L1C  POINT (-47.72240 -23.23417)
# 35  53LNF_0843       5  S13E135_L1C  POINT (135.25442 -12.85853)
# 36  32TLR_0771       5  N45E007_L1C     POINT (7.01145 45.50140)
# 37  55VFL_1257       5  N63E150_L1C   POINT (150.44443 63.38673)
# 38  34WDB_4464       5  N68E020_L1C    POINT (20.37038 68.83025)
# 39  45WWR_6064       5  N68E089_L1C    POINT (89.58653 68.45532)

# %%
date_range = pd.date_range('2020-01-01', '2024-02-14')
date_index = pd.DataFrame(date_range, columns=['date'])
date_subset = date_index.sample(n=samples)

# %%
date_subset
# Out:
#            date
# 503  2021-05-18
# 406  2021-02-10
# 251  2020-09-08
# 142  2020-05-22
# 1284 2023-07-08
# 620  2021-09-12
# 666  2021-10-28
# 392  2021-01-27
# 141  2020-05-21
# 924  2022-07-13
# 909  2022-06-28
# 1361 2023-09-23
# 547  2021-07-01
# 617  2021-09-09
# 166  2020-06-15
# 1332 2023-08-25
# 1290 2023-07-14
# 1156 2023-03-02
# 1203 2023-04-18
# 349  2020-12-15
# 980  2022-09-07
# 562  2021-07-16
# 10   2020-01-11
# 599  2021-08-22
# 1248 2023-06-02
# 669  2021-10-31
# 986  2022-09-13
# 496  2021-05-11
# 317  2020-11-13
# 815  2022-03-26
# 17   2020-01-18
# 1343 2023-09-05
# 76   2020-03-17
# 1352 2023-09-14
# 683  2021-11-14
# 508  2021-05-23
# 1430 2023-12-01
# 713  2021-12-14
# 357  2020-12-23
# 150  2020-05-30

# %%
date_subset.reset_index(drop=True, inplace=True)

# %%
rnd = random_points_gdf.join(date_subset)

# %%
# base URL of the product catalogue
catalogue_odata_url = "https://catalogue.dataspace.copernicus.eu/odata/v1"

# search parameters
collection_name = "SENTINEL-2"
product_type = "S2MSI2A"
max_cloud_cover = 100

# %%
def path_builder(aoi, catalogue_odata_url, collection_name, product_type, max_cloud_cover, search_period_start, search_period_end, root):
    search_query = (f"{catalogue_odata_url}/Products?$filter=Collection/Name eq '{collection_name}' "
                    f"and Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'productType' "
                    f"and att/OData.CSC.StringAttribute/Value eq '{product_type}') "
                    f"and Attributes/OData.CSC.DoubleAttribute/any(att:att/Name eq 'Online' and att/OData.CSC.DoubleAttribute/Value eq 'True') " 
                    f"and OData.CSC.Intersects(area=geography'SRID=4326;{aoi}') "
                    f"and ContentDate/Start gt {search_period_start} "
                    f"and ContentDate/Start lt {search_period_end}")
    
    response = requests.get(search_query)
    if response.status_code == 200:
        response = response.json()
        result = pd.DataFrame.from_dict(response["value"])
        if result.empty:
            print(f"No results for {aoi}")
            return None, None, None
        else:
            random.seed(1492)
            
            if len(result) > 1:
                n = random.randint(0, result.shape[0]-1)
            else:
                n = 0
                
            product_name = result.iloc[n]['Name']
            print(product_name)
        
            nm_component = product_name.split('_')
            yr = nm_component[2][:4] 
            mm = nm_component[2][4:6]
            dd = nm_component[2][6:8]
            
            zone = nm_component[5][1:3]
            row = nm_component[5][3:4]
            square = nm_component[5][4:6]
            CDSE_path = glob.glob(os.path.join(root, 'CDSE', f'Sentinel-2/MSI/L2A/{yr}/{mm}/{dd}/{product_name}/GRANULE/*/IMG_DATA/R20m/*B07_20m.jp2'))
            if len(CDSE_path) > 0:
                CDSE_path = CDSE_path[0]
            else:
                'Processing level not found in the archive'
                return None, None, None
            
            AWS_path = os.path.join(root, 'AWS', f'tiles/{zone}/{row}/{square}/{yr}/{int(mm)}/{int(dd)}/0/R20m/B07.jp2')
            return product_name, CDSE_path, AWS_path
    else:
        print(f'{response.status_code}')
        return None, None, None
    
results = []
repeat_n = 10
number_n = 1
dd_number = 1

for row in rnd.iterrows():
    point = row[1].get(key = 'geometry')
    date = row[1].get(key = 'date')

    search_period_start = (date - Timedelta(dd_number, unit='day')).strftime('%Y-%m-%dT00:00:00.000Z')
    search_period_end = (date + Timedelta(dd_number, unit='day')).strftime('%Y-%m-%dT00:00:00.000Z')
    
    product_name, CDSE_path, AWS_path = path_builder(point, catalogue_odata_url, collection_name, product_type, max_cloud_cover, search_period_start, search_period_end, root)

    print (product_name)
    
    # if product_name:
    # 
    #     timing_CDSE = timeit.repeat(f'gdal.Info(\'{CDSE_path}\')',
    #                            #setup='from osgeo import gdal', 
    #                            repeat=repeat_n, 
    #                            number=number_n, 
    #                            globals=my_globals)
    #     timing_CDSE = np.array(timing_CDSE)/number_n
    #     mean_CDSE = np.mean(timing_CDSE).round(3)
    #     std_CDSE = np.std(timing_CDSE).round(3)
    #     min_CDSE = np.min(timing_CDSE).round(3)
    #     max_CDSE = np.max(timing_CDSE).round(3)
    # 
    #     timing_AWS = timeit.repeat(f'gdal.Info(\'{AWS_path}\')',
    #                            #setup='from osgeo import gdal', 
    #                            repeat=repeat_n, 
    #                            number=number_n, 
    #                            globals=my_globals)
    #     timing_AWS = np.array(timing_AWS)/number_n
    #     mean_aws = np.mean(timing_AWS).round(3)
    #     std_aws = np.std(timing_AWS).round(3)
    #     min_AWS = np.min(timing_AWS).round(3)
    #     max_AWS = np.max(timing_AWS).round(3)
    # 
    #     results.append([product_name, mean_CDSE, min_CDSE, max_CDSE, std_CDSE, mean_aws, min_AWS, max_AWS, std_aws])
results_df = pd.DataFrame(results, columns=['product_name', 'mean_CDSE', 'min_CDSE', 'max_CDSE', 'std_CDSE', 'mean_AWS', 'min_AWS', 'max_AWS', 'std_AWS'])

results_df.to_csv('CDSE_AWS.csv', index=False)
# Out:
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None
# 400
# None

# %%
aoi = rnd.iloc[0].geometry
date = rnd.iloc[0].date

# %%
search_period_start = (date - Timedelta(10, unit='day')).strftime('%Y-%m-%dT00:00:00.000Z')
search_period_end = (date + Timedelta(10, unit='day')).strftime('%Y-%m-%dT00:00:00.000Z')

# %%
search_query = (f"{catalogue_odata_url}/Products?$"
                     f"filter=Collection/Name eq '{collection_name}' "
                     f"and Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'productType' and att/Value eq '{product_type}') "
                     # f"and Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'processorVersion' and att/Value eq '05.00') "                
                     # f"and contains(Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'processorVersion' and att/Value eq '05.00') "                
                     f"and OData.CSC.Intersects(area=geography'SRID=4326;{aoi}') "
                     f"and ContentDate/Start gt {search_period_start} "
                     f"and ContentDate/Start lt {search_period_end}"
                     f"&$expand=Attributes"
                     
                )


    # EntityDefinitions?$select=LogicalName&**$expand=Attributes($select=LogicalName)**&$filter=SchemaName eq 'Contact'
response = requests.get(search_query)

# %%
response = response.json()

# %%
response
# Out:
# {'@odata.context': '$metadata#Products(Attributes())',
#  'value': [{'@odata.mediaContentType': 'application/octet-stream',
#    'Id': '05142707-b950-4d52-89ba-d6978d42fd1f',
#    'Name': 'S2B_MSIL2A_20210820T030539_N0500_R075_T49QEG_20230209T102000.SAFE',
#    'ContentType': 'application/octet-stream',
#    'ContentLength': 1190617302,
#    'OriginDate': '2023-03-24T05:21:41.408Z',
#    'PublicationDate': '2023-03-24T06:37:06.778Z',
#    'ModificationDate': '2024-02-27T16:41:30.805Z',
#    'Online': True,
#    'EvictionDate': '',
#    'S3Path': '/eodata/Sentinel-2/MSI/L2A_N0500/2021/08/20/S2B_MSIL2A_20210820T030539_N0500_R075_T49QEG_20230209T102000.SAFE',
#    'Checksum': [{'Value': '3daf348a299474d567a96540dbd27223',
#      'Algorithm': 'MD5',
#      'ChecksumDate': '2024-02-27T16:41:28.142921Z'},
#     {'Value': '49fe9c2063aa019d1ca491ad97d69a44dea9249a130b0e6dbd4b7fb08c535b9f',
#      'Algorithm': 'BLAKE3',
#      'ChecksumDate': '2024-02-27T16:41:30.680188Z'}],
#    'ContentDate': {'Start': '2021-08-20T03:05:39.024Z',
#     'End': '2021-08-20T03:05:39.024Z'},
#    'Footprint': "geography'SRID=4326;POLYGON ((110.999802729247 24.4134279074122, 110.999804229489 23.4216721787737, 112.074511091875 23.4179763365823, 112.082743406641 24.4095560019498, 110.999802729247 24.4134279074122))'",
#    'GeoFootprint': {'type': 'Polygon',
#     'coordinates': [[[110.999802729247, 24.4134279074122],
#       [110.999804229489, 23.4216721787737],
#       [112.074511091875, 23.4179763365823],
#       [112.082743406641, 24.4095560019498],
#       [110.999802729247, 24.4134279074122]]]},
#    'Attributes': [{'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'origin',
#      'Value': 'ESA',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'tileId',
#      'Value': '49QEG',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.DoubleAttribute',
#      'Name': 'cloudCover',
#      'Value': 47.18979,
#      'ValueType': 'Double'},
#     {'@odata.type': '#OData.CSC.IntegerAttribute',
#      'Name': 'orbitNumber',
#      'Value': 23267,
#      'ValueType': 'Integer'},
#     {'@odata.type': '#OData.CSC.DateTimeOffsetAttribute',
#      'Name': 'processingDate',
#      'Value': '2023-02-09T10:20:00+00:00',
#      'ValueType': 'DateTimeOffset'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'productGroupId',
#      'Value': 'GS2B_20210820T030539_023267_N05.00',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'processingLevel',
#      'Value': 'S2MSI2A',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'processorVersion',
#      'Value': '05.00',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'platformShortName',
#      'Value': 'SENTINEL-2',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'instrumentShortName',
#      'Value': 'MSI',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.IntegerAttribute',
#      'Name': 'relativeOrbitNumber',
#      'Value': 75,
#      'ValueType': 'Integer'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'platformSerialIdentifier',
#      'Value': 'B',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'productType',
#      'Value': 'S2MSI2A',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.DateTimeOffsetAttribute',
#      'Name': 'beginningDateTime',
#      'Value': '2021-08-20T03:05:39.024Z',
#      'ValueType': 'DateTimeOffset'},
#     {'@odata.type': '#OData.CSC.DateTimeOffsetAttribute',
#      'Name': 'endingDateTime',
#      'Value': '2021-08-20T03:05:39.024Z',
#      'ValueType': 'DateTimeOffset'}]},
#   {'@odata.mediaContentType': 'application/octet-stream',
#    'Id': '51a9a258-178a-4b81-a6e6-7c11e46884f0',
#    'Name': 'S2A_MSIL2A_20210805T030551_N0500_R075_T49QEG_20230122T213737.SAFE',
#    'ContentType': 'application/octet-stream',
#    'ContentLength': 827030879,
#    'OriginDate': '2023-03-09T04:30:39.736Z',
#    'PublicationDate': '2023-03-09T05:31:40.840Z',
#    'ModificationDate': '2024-02-28T12:08:04.312Z',
#    'Online': True,
#    'EvictionDate': '',
#    'S3Path': '/eodata/Sentinel-2/MSI/L2
N03.01',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'instrumentShortName',
#      'Value': 'MSI',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.IntegerAttribute',
#      'Name': 'relativeOrbitNumber',
#      'Value': 75,
#      'ValueType': 'Integer'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'platformSerialIdentifier',
#      'Value': 'B',
#      'ValueType': 'String'}]},
#   {'@odata.mediaContentType': 'application/octet-stream',
#    'Id': '00764679-cf3f-5704-96ea-99281a09cf14',
#    'Name': 'S2A_MSIL2A_20210815T030551_N0301_R075_T49QEG_20210815T062815.SAFE',
#    'ContentType': 'application/octet-stream',
#    'ContentLength': 0,
#    'OriginDate': '2021-08-15T10:10:14.605Z',
#    'PublicationDate': '2021-08-15T10:24:45.963Z',
#    'ModificationDate': '2021-08-15T10:24:45.963Z',
#    'Online': False,
#    'EvictionDate': '',
#    'S3Path': '/eodata/Sentinel-2/MSI/L2A/2021/08/15/S2A_MSIL2A_20210815T030551_N0301_R075_T49QEG_20210815T062815.SAFE',
#    'Checksum': [],
#    'ContentDate': {'Start': '2021-08-15T03:05:51.024Z',
#     'End': '2021-08-15T03:05:51.024Z'},
#    'Footprint': "geography'SRID=4326;POLYGON ((110.99980272925 24.413427907412, 112.08274340664 24.40955600195, 112.07451109188 23.417976336582, 110.99980422949 23.421672178774, 110.99980272925 24.413427907412))'",
#    'GeoFootprint': {'type': 'Polygon',
#     'coordinates': [[[110.99980272925, 24.413427907412],
#       [112.08274340664, 24.40955600195],
#       [112.07451109188, 23.417976336582],
#       [110.99980422949, 23.421672178774],
#       [110.99980272925, 24.413427907412]]]},
#    'Attributes': [{'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'origin',
#      'Value': 'ESA',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'tileId',
#      'Value': '49QEG',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'authority',
#      'Value': 'ESA',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.DoubleAttribute',
#      'Name': 'cloudCover',
#      'Value': 46.304411,
#      'ValueType': 'Double'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'coordinates',
#      'Value': '24.413427907412203,110.99980272924678 24.409556001949852,112.08274340664086 23.417976336582313,112.07451109187538 23.421672178773655,110.99980422948886 24.413427907412203,110.99980272924678',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.IntegerAttribute',
#      'Name': 'orbitNumber',
#      'Value': 32104,
#      'ValueType': 'Integer'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'productType',
#      'Value': 'S2MSI2A',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.DateTimeOffsetAttribute',
#      'Name': 'endingDateTime',
#      'Value': '2021-08-15T03:05:51.024Z',
#      'ValueType': 'DateTimeOffset'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'orbitDirection',
#      'Value': 'DESCENDING',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'productGroupId',
#      'Value': 'GS2A_20210815T030551_032104_N03.01',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'operationalMode',
#      'Value': '',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'processingLevel',
#      'Value': 'S2MSI2A',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'processorVersion',
#      'Value': '3.01',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.DateTimeOffsetAttribute',
#      'Name': 'beginningDateTime',
#      'Value': '2021-08-15T03:05:51.024Z',
#      'ValueType': 'DateTimeOffset'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'platformShortName',
#      'Value': 'SENTINEL-2',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'spatialResolution',
#      'Value': '60.0',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'datastripidentifier',
#      'Value': 'S2A_OPER_MSI_L2A_DS_VGS4_20210815T062815_S20210815T032022_N03.01',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'instrumentShortName',
#      'Value': 'MSI',
#      'ValueType': 'String'},
#     {'@odata.type': '#OData.CSC.IntegerAttribute',
#      'Name': 'relativeOrbitNumber',
#      'Value': 75,
#      'ValueType': 'Integer'},
#     {'@odata.type': '#OData.CSC.StringAttribute',
#      'Name': 'platformSerialIdentifier',
#      'Value': 'A',
#      'ValueType': 'String'}]}]}

# %%
df = pd.DataFrame.from_dict(response["value"])

# %%
df
# Out:
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  5c9963b7-e845-5b85-91de-723b75807d62
# 1  application/octet-stream  c5db1d6c-35ae-4b24-af55-bcd51a6a4491
# 2  application/octet-stream  9797bd4d-551a-500c-ac3b-a498c1722280
# 3  application/octet-stream  f13220e6-f240-42ba-8914-21147fff43c4
/eodata/Sentinel-2/MSI/L2A_N0500/2021/05/27/S2...
#
#                                             Checksum  \
# 0                                                 []
# 1                                               [{}]
# 2                                                 []
# 3  [{'Value': '2eb0bec26daf3201a5161df82ab77864',...
# 4                                                 []
# 5                                                 []
# 6  [{'Value': '4359434a087f9d131d4bea7808545ae8',...
# 7  [{'Value': 'e0c085d7981d87cc09f2ed452796503e',...
#
#                                          ContentDate  \
# 0  {'Start': '2021-05-22T08:06:09.024Z', 'End': '...
# 1  {'Start': '2021-05-22T08:06:09.024Z', 'End': '...
# 2  {'Start': '2021-05-27T08:06:11.024Z', 'End': '...
# 3  {'Start': '2021-05-12T08:06:09.024Z', 'End': '...
# 4  {'Start': '2021-05-17T08:06:11.024Z', 'End': '...
# 5  {'Start': '2021-05-12T08:06:09.024Z', 'End': '...
# 6  {'Start': '2021-05-17T08:06:11.024Z', 'End': '...
# 7  {'Start': '2021-05-27T08:06:11.024Z', 'End': '...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 1  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 2  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 3  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 4  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 5  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 6  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 7  geography'SRID=4326;POLYGON ((27.904116585344 ...
#
#                                         GeoFootprint  \
# 0  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 1  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 2  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 3  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 4  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 5  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 6  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 7  {'type': 'Polygon', 'coordinates': [[[27.90411...
#
#                                           Attributes
# 0  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 1  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 2  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 3  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 4  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 5  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 6  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 7  [{'@odata.type': '#OData.CSC.StringAttribute',...

# %%
df[(df['ContentLength'] != 0) & (df['Online'] == True) & df['Name'].str.contains('_N05')]
# Out:
#     @odata.mediaContentType                                    Id  \
# 1  application/octet-stream  c5db1d6c-35ae-4b24-af55-bcd51a6a4491
# 3  application/octet-stream  f13220e6-f240-42ba-8914-21147fff43c4
# 6  application/octet-stream  a08fc84f-16a2-420c-85e1-61ab74f553c0
# 7  application/octet-stream  87767598-761a-4e01-808a-5c05f95e542c
#
#                                                 Name  \
# 1  S2B_MSIL2A_20210522T080609_N0500_R078_T35MPN_2...
# 3  S2B_MSIL2A_20210512T080609_N0500_R078_T35MPN_2...
# 6  S2A_MSIL2A_20210517T080611_N0500_R078_T35MPN_2...
# 7  S2A_MSIL2A_20210527T080611_N0500_R078_T35MPN_2...
#
#                 ContentType  ContentLength                OriginDate  \
# 1  application/octet-stream     1142788105  2023-04-20T22:05:28.201Z
# 3  application/octet-stream     1132421574  2023-06-06T06:39:10.358Z
# 6  application/octet-stream      987888051  2023-03-29T16:11:27.785Z
# 7  application/octet-stream     1146073649  2023-03-18T04:34:18.537Z
#
#             PublicationDate          ModificationDate  Online EvictionDate  \
# 1  2023-04-21T00:10:49.427Z  2023-04-21T00:10:49.427Z    True
# 3  2023-06-08T01:09:10.838Z  2023-06-15T05:01:53.683Z    True
# 6  2023-03-29T18:26:31.821Z  2024-03-02T21:09:21.229Z    True
# 7  2023-03-18T06:03:01.881Z  2024-03-02T10:35:17.793Z    True
#
#                                               S3Path  \
# 1  /eodata/Sentinel-2/MSI/L2A_N0500/2021/05/22/S2...
# 3  /eodata/Sentinel-2/MSI/L2A_N0500/2021/05/12/S2...
# 6  /eodata/Sentinel-2/MSI/L2A_N0500/2021/05/17/S2...
# 7  /eodata/Sentinel-2/MSI/L2A_N0500/2021/05/27/S2...
#
#                                             Checksum  \
# 1                                               [{}]
# 3  [{'Value': '2eb0bec26daf3201a5161df82ab77864',...
# 6  [{'Value': '4359434a087f9d131d4bea7808545ae8',...
# 7  [{'Value': 'e0c085d7981d87cc09f2ed452796503e',...
#
#                                          ContentDate  \
# 1  {'Start': '2021-05-22T08:06:09.024Z', 'End': '...
# 3  {'Start': '2021-05-12T08:06:09.024Z', 'End': '...
# 6  {'Start': '2021-05-17T08:06:11.024Z', 'End': '...
# 7  {'Start': '2021-05-27T08:06:11.024Z', 'End': '...
#
#                                            Footprint  \
# 1  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 3  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 6  geography'SRID=4326;POLYGON ((27.904116585344 ...
# 7  geography'SRID=4326;POLYGON ((27.904116585344 ...
#
#                                         GeoFootprint  \
# 1  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 3  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 6  {'type': 'Polygon', 'coordinates': [[[27.90411...
# 7  {'type': 'Polygon', 'coordinates': [[[27.90411...
#
#                                           Attributes
# 1  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 3  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 6  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 7  [{'@odata.type': '#OData.CSC.StringAttribute',...

# %%
df['Name'].str.contains('500')
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# Name: Name, dtype: bool

# %%
df['Name']
# Out:
# 0    S2B_MSIL2A_20210522T080609_N0300_R078_T35MPN_2...
# 1    S2B_MSIL2A_20210522T080609_N0500_R078_T35MPN_2...
# 2    S2A_MSIL2A_20210527T080611_N0300_R078_T35MPN_2...
# 3    S2B_MSIL2A_20210512T080609_N0500_R078_T35MPN_2...
# 4    S2A_MSIL2A_20210517T080611_N0300_R078_T35MPN_2...
# 5    S2B_MSIL2A_20210512T080609_N0300_R078_T35MPN_2...
# 6    S2A_MSIL2A_20210517T080611_N0500_R078_T35MPN_2...
# 7    S2A_MSIL2A_20210527T080611_N0500_R078_T35MPN_2...
# Name: Name, dtype: object

# %%
# pd.DataFrame.from_dict(response["value"]).iloc[0]['Attributes']

# %%
response.values()
# Out:
# dict_values(['$metadata#Products', [{'@odata.mediaContentType': 'application/octet-stream', 'Id': 'bdca8e14-9705-5333-a8d1-c9daea800bbf', 'Name': 'S2A_MSIL2A_20200112T102401_N0213_R065_T32TNS_20200112T115112.SAFE', 'ContentType': 'application/octet-stream', 'ContentLength': 0, 'OriginDate': '2020-01-12T17:29:50.222Z', 'PublicationDate': '2020-01-12T17:42:13.317Z', 'ModificationDate': '2020-01-12T17:42:13.317Z', 'Online': True, 'EvictionDate': '', 'S3Path': '/eodata/Sentinel-2/MSI/L2A/2020/01/12/S2A_MSIL2A_20200112T102401_N0213_R065_T32TNS_20200112T115112.SAFE', 'Checksum': [], 'ContentDate': {'Start': '2020-01-12T10:24:01.024Z', 'End': '2020-01-12T10:24:01.024Z'}, 'Footprint': "geography'SRID=4326;POLYGON ((8.9997371575622 46.953709179213, 10.442508097945 46.944621441403, 10.416656101607 45.956769859076, 8.9997418700468 45.965551148516, 8.9997371575622 46.953709179213))'", 'GeoFootprint': {'type': 'Polygon', 'coordinates': [[[8.9997371575622, 46.953709179213], [10.442508097945, 46.944621441403], [10.416656101607, 45.956769859076], [8.9997418700468, 45.965551148516], [8.9997371575622, 46.953709179213]]]}}, {'@odata.mediaContentType': 'application/octet-stream', 'Id': '0cd7883c-aad3-418f-8a61-09343a9fc8f7', 'Name': 'S2B_MSIL2A_20200117T102249_N0500_R065_T32TNS_20230611T221314.SAFE', 'ContentType': 'application/octet-